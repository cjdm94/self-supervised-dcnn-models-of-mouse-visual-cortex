# %%
from cortexlib.utils.plotting import plot_mean_fev
import matplotlib.pyplot as plt
from matplotlib.patches import Patch
from pathlib import Path
import pandas as pd
import json

paths = [
    Path("../../../analysis/mouse_m01_d2/results/simclr_neural_pc1_m01_d2.json"),
    Path("../../../analysis/mouse_m02_d3/results/simclr_neural_pc1_m02_d3.json"),
    Path("../../../analysis/mouse_m03_d4/results/simclr_neural_pc1_m03_d4.json"),
    Path("../../../analysis/mouse_m01_d2/results/vgg19_neural_pc1_m01_d2.json"),
    Path("../../../analysis/mouse_m02_d3/results/vgg19_neural_pc1_m02_d3.json"),
    Path("../../../analysis/mouse_m03_d4/results/vgg19_neural_pc1_m03_d4.json"),
    Path("../../../analysis/mouse_m01_d2/results/gabor_neural_pc1_m01_d2.json"),
    Path("../../../analysis/mouse_m02_d3/results/gabor_neural_pc1_m02_d3.json"),
    Path("../../../analysis/mouse_m03_d4/results/gabor_neural_pc1_m03_d4.json"),
]

all_data = []
for path in paths:
    with open(path, "r") as f:
        data = json.load(f)
        all_data.extend(data)

df = pd.DataFrame(all_data)
df = df.sort_values(["mouse_id", "layer", "n_pcs"], na_position='first').reset_index(drop=True)

print(f"Loaded {len(df)} rows from {len(paths)} files.")
df.head(100)
# Out:
# Loaded 264 rows from 9 files.
#         model_target mouse_id    layer  n_pcs  test_r2  mean_fev  alpha  \
# 0   vgg19_neural_pc1   m01_d2  conv2_2    NaN    0.407     0.431  1.396
# 1   vgg19_neural_pc1   m01_d2  conv2_2   10.0    0.342     0.362  1.396
# 2   vgg19_neural_pc1   m01_d2  conv2_2   20.0    0.367     0.389  1.396
# 3   vgg19_neural_pc1   m01_d2  conv2_2   50.0    0.404     0.427  1.396
# 4   vgg19_neural_pc1   m01_d2  conv2_2  100.0    0.407     0.431  1.396
# ..               ...      ...      ...    ...      ...       ...    ...
# 95  vgg19_neural_pc1   m02_d3  conv3_4   20.0    0.425     0.463  1.524
# 96  vgg19_neural_pc1   m02_d3  conv3_4   50.0    0.422     0.460  1.524
# 97  vgg19_neural_pc1   m02_d3  conv3_4  100.0    0.430     0.469  1.524
# 98  vgg19_neural_pc1   m02_d3  conv4_4    NaN    0.402     0.438  1.627
# 99  vgg19_neural_pc1   m02_d3  conv4_4   10.0    0.382     0.417  1.627
#
#     alpha_no_pc1  spearman_correlation  silhouette_score
# 0          1.423                 0.152               NaN
# 1          1.423                 0.172            -0.099
# 2          1.423                 0.169            -0.094
# 3          1.423                 0.167            -0.087
# 4          1.423                 0.166            -0.091
# ..           ...                   ...               ...
# 95         1.542                 0.164            -0.063
# 96         1.542                 0.166            -0.062
# 97         1.542                 0.167            -0.056
# 98         1.664                 0.167               NaN
# 99         1.664                 0.125             0.002
#
# [100 rows x 10 columns]

# %%
# Filter to only rows where: for SimCLR and VGG19, 100 pcs; for Gabor, 10 pcs
df_pcs = df[
    ((df["model_target"].isin(["simclr_neural_pc1", "vgg19_neural_pc1"])) & (df["n_pcs"] == 100)) |
    ((df["model_target"] == "gabor_neural_pc1") & (df["n_pcs"] == 10))
]
df_pcs
# Out:
#           model_target mouse_id         layer  n_pcs  test_r2  mean_fev  \
# 4     vgg19_neural_pc1   m01_d2       conv2_2  100.0    0.407     0.431
# 9     vgg19_neural_pc1   m01_d2       conv3_4  100.0    0.407     0.430
# 14    vgg19_neural_pc1   m01_d2       conv4_4  100.0    0.394     0.417
# 19    vgg19_neural_pc1   m01_d2       conv5_4  100.0    0.279     0.296
# 24   simclr_neural_pc1   m01_d2            fc  100.0    0.477     0.503
# 33    vgg19_neural_pc1   m01_d2           fc2  100.0    0.263     0.280
# 38    gabor_neural_pc1   m01_d2   gabor_large   10.0   -0.004     0.000
# 44    gabor_neural_pc1   m01_d2  gabor_medium   10.0   -0.016     0.000
# 50    gabor_neural_pc1   m01_d2   gabor_small   10.0   -0.018     0.000
# 56   simclr_neural_pc1   m01_d2        layer1  100.0    0.425     0.450
# 65   simclr_neural_pc1   m01_d2        layer2  100.0    0.485     0.513
# 74   simclr_neural_pc1   m01_d2        layer3  100.0    0.490     0.517
# 83   simclr_neural_pc1   m01_d2        layer4  100.0    0.470     0.496
# 92    vgg19_neural_pc1   m02_d3       conv2_2  100.0    0.447     0.488
# 97    vgg19_neural_pc1   m02_d3       conv3_4  100.0    0.430     0.469
# 102   vgg19_neural_pc1   m02_d3       conv4_4  100.0    0.391     0.427
# 107   vgg19_neural_pc1   m02_d3       conv5_4  100.0    0.300     0.328
# 112  simclr_neural_pc1   m02_d3            fc  100.0    0.483     0.527
# 121   vgg19_neural_pc1   m02_d3           fc2  100.0    0.303     0.332
# 126   gabor_neural_pc1   m02_d3   gabor_large   10.0   -0.004     0.000
# 132   gabor_neural_pc1   m02_d3  gabor_medium   10.0   -0.004     0.000
# 138   gabor_neural_pc1   m02_d3   gabor_small   10.0   -0.005     0.000
# 144  simclr_neural_pc1   m02_d3        layer1  100.0    0.441     0.481
# 153  simclr_neural_pc1   m02_d3        layer2  100.0    0.485     0.529
# 162  simclr_neural_pc1   m02_d3        layer3  100.0    0.555     0.604
# 171  simclr_neural_pc1   m02_d3        layer4  100.0    0.530     0.577
# 180   vgg19_neural_pc1   m03_d4       conv2_2  100.0    0.317     0.336
# 185   vgg19_neural_pc1   m03_d4       conv3_4  100.0    0.298     0.315
# 190   vgg19_neural_pc1   m03_d4       conv4_4  100.0    0.272     0.289
# 195   vgg19_neural_pc1   m03_d4       conv5_4  100.0    0.234     0.249
# 200  simclr_neural_pc1   m03_d4            fc  100.0    0.405     0.428
# 209   vgg19_neural_pc1   m03_d4           fc2  100.0    0.204     0.218
# 214   gabor_neural_pc1   m03_d4   gabor_large   10.0   -0.003     0.000
# 220   gabor_neural_pc1   m03_d4  gabor_medium   10.0   -0.004     0.000
# 226   gabor_neural_pc1   m03_d4   gabor_small   10.0    0.002     0.006
# 232  simclr_neural_pc1   m03_d4        layer1  100.0    0.380     0.401
# 241  simclr_neural_pc1   m03_d4        layer2  100.0    0.443     0.468
# 250  simclr_neural_pc1   m03_d4        layer3  100.0    0.444     0.469
# 259  simclr_neural_pc1   m03_d4        layer4  100.0    0.409     0.432
#
#      alpha  alpha_no_pc1  spearman_correlation  silhouette_score
# 4    1.396         1.423                 0.166            -0.091
# 9    1.515         1.462                 0.202            -0.056
# 14   1.616         1.645                 0.169             0.000
# 19   1.867         1.698                 0.125             0.252
# 24   1.702         1.711                 0.188             0.108
# 33   1.583         1.589                 0.107             0.447
# 38     NaN           NaN                   NaN               NaN
# 44     NaN           NaN                   NaN               NaN
# 50     NaN           NaN                   NaN               NaN
# 56   3.891         4.271                 0.168            -0.114
# 65   3.487         3.872                 0.151            -0.080
# 74   1.911         1.917                 0.182            -0.005
# 83   1.887         1.894                 0.143             0.085
# 92   1.394         1.418                 0.128            -0.091
# 97   1.524         1.542                 0.167            -0.056
# 102  1.627         1.664                 0.135             0.000
# 107  1.677         1.709                 0.072             0.252
# 112  1.704         1.712                 0.127             0.108
# 121  1.593         1.602                 0.071             0.447
# 126    NaN           NaN                   NaN               NaN
# 132    NaN           NaN                   NaN               NaN
# 138    NaN           NaN                   NaN               NaN
# 144  3.812         4.127                 0.120            -0.114
# 153  3.438         3.883                 0.096            -0.080
# 162  1.874         1.878                 0.123            -0.005
# 171  1.881         1.888                 0.095             0.085
# 180  1.397         1.423                 0.056            -0.091
# 185  1.514         1.535                 0.048            -0.056
# 190  1.629         1.652                 0.038             0.000
# 195  1.830         1.719                 0.041             0.252
# 200  1.703         1.714                 0.098             0.108
# 209  1.588         1.580                 0.031             0.447
# 214    NaN           NaN                   NaN               NaN
# 220    NaN           NaN                   NaN               NaN
# 226    NaN           NaN                   NaN               NaN
# 232  3.757         4.211                 0.099            -0.114
# 241  3.465         4.031                 0.120            -0.080
# 250  1.889         1.894                 0.118            -0.005
# 259  1.879         1.886                 0.082             0.085

# %%
# Group by layer and compute mean of each metric
avg_metrics = df_pcs.groupby(["model_target", "layer"]).mean(numeric_only=True).reset_index()
avg_metrics
# Out:
#          model_target         layer  n_pcs   test_r2  mean_fev     alpha  \
# 0    gabor_neural_pc1   gabor_large   10.0 -0.003667  0.000000       NaN
# 1    gabor_neural_pc1  gabor_medium   10.0 -0.008000  0.000000       NaN
# 2    gabor_neural_pc1   gabor_small   10.0 -0.007000  0.002000       NaN
# 3   simclr_neural_pc1            fc  100.0  0.455000  0.486000  1.703000
# 4   simclr_neural_pc1        layer1  100.0  0.415333  0.444000  3.820000
# 5   simclr_neural_pc1        layer2  100.0  0.471000  0.503333  3.463333
# 6   simclr_neural_pc1        layer3  100.0  0.496333  0.530000  1.891333
# 7   simclr_neural_pc1        layer4  100.0  0.469667  0.501667  1.882333
# 8    vgg19_neural_pc1       conv2_2  100.0  0.390333  0.418333  1.395667
# 9    vgg19_neural_pc1       conv3_4  100.0  0.378333  0.404667  1.517667
# 10   vgg19_neural_pc1       conv4_4  100.0  0.352333  0.377667  1.624000
# 11   vgg19_neural_pc1       conv5_4  100.0  0.271000  0.291000  1.791333
# 12   vgg19_neural_pc1           fc2  100.0  0.256667  0.276667  1.588000
#
#     alpha_no_pc1  spearman_correlation  silhouette_score
# 0            NaN                   NaN               NaN
# 1            NaN                   NaN               NaN
# 2            NaN                   NaN               NaN
# 3       1.712333              0.137667             0.108
# 4       4.203000              0.129000            -0.114
# 5       3.928667              0.122333            -0.080
# 6       1.896333              0.141000            -0.005
# 7       1.889333              0.106667             0.085
# 8       1.421333              0.116667            -0.091
# 9       1.513000              0.139000            -0.056
# 10      1.653667              0.114000             0.000
# 11      1.708667              0.079333             0.252
# 12      1.590333              0.069667             0.447

# %%
# Get model name
avg_metrics["model"] = avg_metrics["model_target"].str.extract(r"(simclr|vgg19|gabor)")

# Remove Gabor prefix from label
avg_metrics["layer"] = avg_metrics["layer"].str.replace(r"^gabor_", "", regex=True)

# Compute SEM and merge
sem_df = df_pcs.groupby('layer')['mean_fev'].sem().reset_index()
sem_df.columns = ['layer', 'sem_fev']
avg_metrics = avg_metrics.merge(sem_df, on='layer', how='left')

avg_metrics
# Out:
#          model_target    layer  n_pcs   test_r2  mean_fev     alpha  \
# 0    gabor_neural_pc1    large   10.0 -0.003667  0.000000       NaN
# 1    gabor_neural_pc1   medium   10.0 -0.008000  0.000000       NaN
# 2    gabor_neural_pc1    small   10.0 -0.007000  0.002000       NaN
# 3   simclr_neural_pc1       fc  100.0  0.455000  0.486000  1.703000
# 4   simclr_neural_pc1   layer1  100.0  0.415333  0.444000  3.820000
# 5   simclr_neural_pc1   layer2  100.0  0.471000  0.503333  3.463333
# 6   simclr_neural_pc1   layer3  100.0  0.496333  0.530000  1.891333
# 7   simclr_neural_pc1   layer4  100.0  0.469667  0.501667  1.882333
# 8    vgg19_neural_pc1  conv2_2  100.0  0.390333  0.418333  1.395667
# 9    vgg19_neural_pc1  conv3_4  100.0  0.378333  0.404667  1.517667
# 10   vgg19_neural_pc1  conv4_4  100.0  0.352333  0.377667  1.624000
# 11   vgg19_neural_pc1  conv5_4  100.0  0.271000  0.291000  1.791333
# 12   vgg19_neural_pc1      fc2  100.0  0.256667  0.276667  1.588000
#
#     alpha_no_pc1  spearman_correlation  silhouette_score   model   sem_fev
# 0            NaN                   NaN               NaN   gabor       NaN
# 1            NaN                   NaN               NaN   gabor       NaN
# 2            NaN                   NaN               NaN   gabor       NaN
# 3       1.712333              0.137667             0.108  simclr  0.029816
# 4       4.203000              0.129000            -0.114  simclr  0.023288
# 5       3.928667              0.122333            -0.080  simclr  0.018260
# 6       1.896333              0.141000            -0.005  simclr  0.039509
# 7       1.889333              0.106667             0.085  simclr  0.041954
# 8       1.421333              0.116667            -0.091   vgg19  0.044333
# 9       1.513000              0.139000            -0.056   vgg19  0.046225
# 10      1.653667              0.114000             0.000   vgg19  0.044427
# 11      1.708667              0.079333             0.252   vgg19  0.022942
# 12      1.590333              0.069667             0.447   vgg19  0.032951

# %%
plt = plot_mean_fev(avg_metrics, df_pcs, remove_gabor=True)
plt.savefig("./figures/prediction_neural_pc1.svg", format='svg')
plt.show()
# Out:
# /Users/callummessiter/workspace/msc-neuro/research-project/cortexlib/cortexlib/utils/plotting.py:42: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["layer"] = df["layer"].str.replace(r"^gabor_", "", regex=True)
# /Users/callummessiter/workspace/msc-neuro/research-project/cortexlib/cortexlib/utils/plotting.py:43: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["layer"] = pd.Categorical(
