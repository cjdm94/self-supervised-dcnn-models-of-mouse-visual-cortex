# %%
from cortexlib.utils.plotting import plot_mean_fev
from pathlib import Path
import pandas as pd
import json

paths = [
    Path("../../analysis/mouse_m01_d2/results/simclr_neural_m01_d2.json"),
    Path("../../analysis/mouse_m02_d3/results/simclr_neural_m02_d3.json"),
    Path("../../analysis/mouse_m03_d4/results/simclr_neural_m03_d4.json"),
    Path("../../analysis/mouse_m01_d2/results/vgg19_neural_m01_d2.json"),
    Path("../../analysis/mouse_m02_d3/results/vgg19_neural_m02_d3.json"),
    Path("../../analysis/mouse_m03_d4/results/vgg19_neural_m03_d4.json"),
    Path("../../analysis/mouse_m01_d2/results/gabor_neural_m01_d2.json"),
    Path("../../analysis/mouse_m02_d3/results/gabor_neural_m02_d3.json"),
    Path("../../analysis/mouse_m03_d4/results/gabor_neural_m03_d4.json"),
]

all_data = []
for path in paths:
    with open(path, "r") as f:
        data = json.load(f)
        all_data.extend(data)

df = pd.DataFrame(all_data)
df = df.sort_values(["mouse_id", "layer", "n_pcs"], na_position='first').reset_index(drop=True)

print(f"Loaded {len(df)} rows from {len(paths)} files.")
df.head(100)
# Out:
# Loaded 264 rows from 9 files.
#     model_target mouse_id    layer  n_pcs  test_r2  mean_fev  alpha  \
# 0   vgg19_neural   m01_d2  conv2_2    NaN    0.021     0.129  1.396
# 1   vgg19_neural   m01_d2  conv2_2   10.0    0.018     0.110  1.396
# 2   vgg19_neural   m01_d2  conv2_2   20.0    0.019     0.111  1.396
# 3   vgg19_neural   m01_d2  conv2_2   50.0    0.021     0.129  1.396
# 4   vgg19_neural   m01_d2  conv2_2  100.0    0.021     0.129  1.396
# ..           ...      ...      ...    ...      ...       ...    ...
# 95  vgg19_neural   m02_d3  conv3_4   20.0    0.015     0.104  1.524
# 96  vgg19_neural   m02_d3  conv3_4   50.0    0.015     0.105  1.524
# 97  vgg19_neural   m02_d3  conv3_4  100.0    0.015     0.105  1.524
# 98  vgg19_neural   m02_d3  conv4_4    NaN    0.015     0.132  1.627
# 99  vgg19_neural   m02_d3  conv4_4   10.0    0.013     0.118  1.627
#
#     alpha_no_pc1  spearman_correlation  silhouette_score
# 0          1.423                 0.114               NaN
# 1          1.423                 0.184            -0.099
# 2          1.423                 0.180            -0.094
# 3          1.423                 0.177            -0.087
# 4          1.423                 0.177            -0.091
# ..           ...                   ...               ...
# 95         1.542                 0.119            -0.063
# 96         1.542                 0.120            -0.062
# 97         1.542                 0.120            -0.056
# 98         1.664                 0.024               NaN
# 99         1.664                 0.092             0.002
#
# [100 rows x 10 columns]

# %%
# Filter to only rows where: for SimCLR and VGG19, 100 pcs; for Gabor, 10 pcs
df_pcs = df[
    ((df["model_target"].isin(["simclr_neural", "vgg19_neural"])) & (df["n_pcs"] == 100)) |
    ((df["model_target"] == "gabor_neural") & (df["n_pcs"] == 10))
]
df_pcs
# Out:
#       model_target mouse_id         layer  n_pcs  test_r2  mean_fev  alpha  \
# 4     vgg19_neural   m01_d2       conv2_2  100.0    0.021     0.129  1.396
# 9     vgg19_neural   m01_d2       conv3_4  100.0    0.018     0.109  1.515
# 14    vgg19_neural   m01_d2       conv4_4  100.0    0.019     0.128  1.616
# 19    vgg19_neural   m01_d2       conv5_4  100.0    0.012     0.099  1.867
# 24   simclr_neural   m01_d2            fc  100.0    0.024     0.160  1.702
# 33    vgg19_neural   m01_d2           fc2  100.0    0.010     0.095  1.583
# 38    gabor_neural   m01_d2   gabor_large   10.0   -0.006     0.024    NaN
# 44    gabor_neural   m01_d2  gabor_medium   10.0   -0.006     0.024    NaN
# 50    gabor_neural   m01_d2   gabor_small   10.0   -0.006     0.024    NaN
# 56   simclr_neural   m01_d2        layer1  100.0    0.022     0.114  3.891
# 65   simclr_neural   m01_d2        layer2  100.0    0.043     0.178  3.487
# 74   simclr_neural   m01_d2        layer3  100.0    0.046     0.172  1.911
# 83   simclr_neural   m01_d2        layer4  100.0    0.029     0.132  1.887
# 92    vgg19_neural   m02_d3       conv2_2  100.0    0.016     0.110  1.394
# 97    vgg19_neural   m02_d3       conv3_4  100.0    0.015     0.105  1.524
# 102   vgg19_neural   m02_d3       conv4_4  100.0    0.015     0.131  1.627
# 107   vgg19_neural   m02_d3       conv5_4  100.0    0.009     0.101  1.677
# 112  simclr_neural   m02_d3            fc  100.0    0.017     0.113  1.704
# 121   vgg19_neural   m02_d3           fc2  100.0    0.008     0.100  1.593
# 126   gabor_neural   m02_d3   gabor_large   10.0   -0.004     0.034    NaN
# 132   gabor_neural   m02_d3  gabor_medium   10.0   -0.004     0.034    NaN
# 138   gabor_neural   m02_d3   gabor_small   10.0   -0.004     0.034    NaN
# 144  simclr_neural   m02_d3        layer1  100.0    0.020     0.113  3.812
# 153  simclr_neural   m02_d3        layer2  100.0    0.040     0.194  3.438
# 162  simclr_neural   m02_d3        layer3  100.0    0.042     0.183  1.874
# 171  simclr_neural   m02_d3        layer4  100.0    0.027     0.142  1.881
# 180   vgg19_neural   m03_d4       conv2_2  100.0    0.013     0.089  1.397
# 185   vgg19_neural   m03_d4       conv3_4  100.0    0.012     0.083  1.514
# 190   vgg19_neural   m03_d4       conv4_4  100.0    0.011     0.104  1.629
# 195   vgg19_neural   m03_d4       conv5_4  100.0    0.008     0.080  1.830
# 200  simclr_neural   m03_d4            fc  100.0    0.016     0.090  1.703
# 209   vgg19_neural   m03_d4           fc2  100.0    0.006     0.079  1.588
# 214   gabor_neural   m03_d4   gabor_large   10.0   -0.004     0.022    NaN
# 220   gabor_neural   m03_d4  gabor_medium   10.0   -0.004     0.022    NaN
# 226   gabor_neural   m03_d4   gabor_small   10.0   -0.004     0.023    NaN
# 232  simclr_neural   m03_d4        layer1  100.0    0.019     0.101  3.757
# 241  simclr_neural   m03_d4        layer2  100.0    0.034     0.163  3.465
# 250  simclr_neural   m03_d4        layer3  100.0    0.035     0.150  1.889
# 259  simclr_neural   m03_d4        layer4  100.0    0.022     0.110  1.879
#
#      alpha_no_pc1  spearman_correlation  silhouette_score
# 4           1.423                 0.177            -0.091
# 9           1.462                 0.199            -0.056
# 14          1.645                 0.160             0.000
# 19          1.698                 0.122             0.252
# 24          1.711                 0.214             0.108
# 33          1.589                 0.093             0.447
# 38            NaN                   NaN               NaN
# 44            NaN                   NaN               NaN
# 50            NaN                   NaN               NaN
# 56          4.271                 0.225            -0.114
# 65          3.872                 0.233            -0.080
# 74          1.917                 0.245            -0.005
# 83          1.894                 0.193             0.085
# 92          1.418                 0.112            -0.091
# 97          1.542                 0.120            -0.056
# 102         1.664                 0.097             0.000
# 107         1.709                 0.074             0.252
# 112         1.712                 0.156             0.108
# 121         1.602                 0.061             0.447
# 126           NaN                   NaN               NaN
# 132           NaN                   NaN               NaN
# 138           NaN                   NaN               NaN
# 144         4.127                 0.185            -0.114
# 153         3.883                 0.202            -0.080
# 162         1.878                 0.204            -0.005
# 171         1.888                 0.159             0.085
# 180         1.423                 0.122            -0.091
# 185         1.535                 0.120            -0.056
# 190         1.652                 0.098             0.000
# 195         1.719                 0.079             0.252
# 200         1.714                 0.153             0.108
# 209         1.580                 0.058             0.447
# 214           NaN                   NaN               NaN
# 220           NaN                   NaN               NaN
# 226           NaN                   NaN               NaN
# 232         4.211                 0.175            -0.114
# 241         4.031                 0.193            -0.080
# 250         1.894                 0.191            -0.005
# 259         1.886                 0.144             0.085

# %%
# Group by layer and compute mean of each metric
avg_metrics = df_pcs.groupby(["model_target", "layer"]).mean(numeric_only=True).reset_index()
avg_metrics
# Out:
#      model_target         layer  n_pcs   test_r2  mean_fev     alpha  \
# 0    gabor_neural   gabor_large   10.0 -0.004667  0.026667       NaN
# 1    gabor_neural  gabor_medium   10.0 -0.004667  0.026667       NaN
# 2    gabor_neural   gabor_small   10.0 -0.004667  0.027000       NaN
# 3   simclr_neural            fc  100.0  0.019000  0.121000  1.703000
# 4   simclr_neural        layer1  100.0  0.020333  0.109333  3.820000
# 5   simclr_neural        layer2  100.0  0.039000  0.178333  3.463333
# 6   simclr_neural        layer3  100.0  0.041000  0.168333  1.891333
# 7   simclr_neural        layer4  100.0  0.026000  0.128000  1.882333
# 8    vgg19_neural       conv2_2  100.0  0.016667  0.109333  1.395667
# 9    vgg19_neural       conv3_4  100.0  0.015000  0.099000  1.517667
# 10   vgg19_neural       conv4_4  100.0  0.015000  0.121000  1.624000
# 11   vgg19_neural       conv5_4  100.0  0.009667  0.093333  1.791333
# 12   vgg19_neural           fc2  100.0  0.008000  0.091333  1.588000
#
#     alpha_no_pc1  spearman_correlation  silhouette_score
# 0            NaN                   NaN               NaN
# 1            NaN                   NaN               NaN
# 2            NaN                   NaN               NaN
# 3       1.712333              0.174333             0.108
# 4       4.203000              0.195000            -0.114
# 5       3.928667              0.209333            -0.080
# 6       1.896333              0.213333            -0.005
# 7       1.889333              0.165333             0.085
# 8       1.421333              0.137000            -0.091
# 9       1.513000              0.146333            -0.056
# 10      1.653667              0.118333             0.000
# 11      1.708667              0.091667             0.252
# 12      1.590333              0.070667             0.447

# %%
# Get model name
avg_metrics["model"] = avg_metrics["model_target"].str.extract(r"(simclr|vgg19|gabor)")

# Remove Gabor prefix from label
avg_metrics["layer"] = avg_metrics["layer"].str.replace(r"^gabor_", "", regex=True)

# Compute SEM and merge
sem_df = df_pcs.groupby('layer')['mean_fev'].sem().reset_index()
sem_df.columns = ['layer', 'sem_fev']
avg_metrics = avg_metrics.merge(sem_df, on='layer', how='left')

avg_metrics
# Out:
#      model_target    layer  n_pcs   test_r2  mean_fev     alpha  alpha_no_pc1  \
# 0    gabor_neural    large   10.0 -0.004667  0.026667       NaN           NaN
# 1    gabor_neural   medium   10.0 -0.004667  0.026667       NaN           NaN
# 2    gabor_neural    small   10.0 -0.004667  0.027000       NaN           NaN
# 3   simclr_neural       fc  100.0  0.019000  0.121000  1.703000      1.712333
# 4   simclr_neural   layer1  100.0  0.020333  0.109333  3.820000      4.203000
# 5   simclr_neural   layer2  100.0  0.039000  0.178333  3.463333      3.928667
# 6   simclr_neural   layer3  100.0  0.041000  0.168333  1.891333      1.896333
# 7   simclr_neural   layer4  100.0  0.026000  0.128000  1.882333      1.889333
# 8    vgg19_neural  conv2_2  100.0  0.016667  0.109333  1.395667      1.421333
# 9    vgg19_neural  conv3_4  100.0  0.015000  0.099000  1.517667      1.513000
# 10   vgg19_neural  conv4_4  100.0  0.015000  0.121000  1.624000      1.653667
# 11   vgg19_neural  conv5_4  100.0  0.009667  0.093333  1.791333      1.708667
# 12   vgg19_neural      fc2  100.0  0.008000  0.091333  1.588000      1.590333
#
#     spearman_correlation  silhouette_score   model   sem_fev
# 0                    NaN               NaN   gabor       NaN
# 1                    NaN               NaN   gabor       NaN
# 2                    NaN               NaN   gabor       NaN
# 3               0.174333             0.108  simclr  0.020599
# 4               0.195000            -0.114  simclr  0.004177
# 5               0.209333            -0.080  simclr  0.008950
# 6               0.213333            -0.005  simclr  0.009701
# 7               0.165333             0.085  simclr  0.009452
# 8               0.137000            -0.091   vgg19  0.011552
# 9               0.146333            -0.056   vgg19  0.008083
# 10              0.118333             0.000   vgg19  0.008544
# 11              0.091667             0.252   vgg19  0.006692
# 12              0.070667             0.447   vgg19  0.006333

# %%
plt = plot_mean_fev(avg_metrics, df_pcs)
plt.savefig("./figures/prediction_neural.svg", format='svg')
plt.show()
# Out:
# /Users/callummessiter/workspace/msc-neuro/research-project/cortexlib/cortexlib/utils/plotting.py:42: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["layer"] = df["layer"].str.replace(r"^gabor_", "", regex=True)
# /Users/callummessiter/workspace/msc-neuro/research-project/cortexlib/cortexlib/utils/plotting.py:43: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["layer"] = pd.Categorical(
