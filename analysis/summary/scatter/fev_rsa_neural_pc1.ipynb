# %%
from cortexlib.utils.plotting import plot_fev_vs_metric_scatter
from cortexlib.utils.plotting import simclr_colours, vgg19_colours
from scipy.stats import spearmanr
import matplotlib.pyplot as plt
from pathlib import Path
import pandas as pd
import json

paths = [
    Path("../../../analysis/mouse_m01_d2/results/simclr_neural_pc1_m01_d2.json"),
    Path("../../../analysis/mouse_m02_d3/results/simclr_neural_pc1_m02_d3.json"),
    Path("../../../analysis/mouse_m03_d4/results/simclr_neural_pc1_m03_d4.json"),
    Path("../../../analysis/mouse_m01_d2/results/vgg19_neural_pc1_m01_d2.json"),
    Path("../../../analysis/mouse_m02_d3/results/vgg19_neural_pc1_m02_d3.json"),
    Path("../../../analysis/mouse_m03_d4/results/vgg19_neural_pc1_m03_d4.json"),
]

all_data = []
for path in paths:
    with open(path, "r") as f:
        data = json.load(f)
        all_data.extend(data)

df = pd.DataFrame(all_data)
df = df.sort_values(["mouse_id", "layer", "n_pcs"], na_position='first').reset_index(drop=True)

print(f"Loaded {len(df)} rows from {len(paths)} files.")
df.head(100)
# Out:
# Loaded 210 rows from 6 files.
#          model_target mouse_id    layer  n_pcs  test_r2  mean_fev  alpha  \
# 0    vgg19_neural_pc1   m01_d2  conv2_2    NaN    0.407     0.431  1.396
# 1    vgg19_neural_pc1   m01_d2  conv2_2   10.0    0.342     0.362  1.396
# 2    vgg19_neural_pc1   m01_d2  conv2_2   20.0    0.367     0.389  1.396
# 3    vgg19_neural_pc1   m01_d2  conv2_2   50.0    0.404     0.427  1.396
# 4    vgg19_neural_pc1   m01_d2  conv2_2  100.0    0.407     0.431  1.396
# ..                ...      ...      ...    ...      ...       ...    ...
# 95  simclr_neural_pc1   m02_d3       fc  200.0    0.510     0.555  1.704
# 96  simclr_neural_pc1   m02_d3       fc  300.0    0.512     0.557  1.704
# 97  simclr_neural_pc1   m02_d3       fc  400.0    0.514     0.560  1.704
# 98  simclr_neural_pc1   m02_d3       fc  500.0    0.512     0.558  1.704
# 99   vgg19_neural_pc1   m02_d3      fc2    NaN    0.306     0.334  1.593
#
#     alpha_no_pc1  spearman_correlation  silhouette_score  \
# 0          1.423                 0.152               NaN
# 1          1.423                 0.172            -0.099
# 2          1.423                 0.169            -0.094
# 3          1.423                 0.167            -0.087
# 4          1.423                 0.166            -0.091
# ..           ...                   ...               ...
# 95         1.712                 0.128             0.107
# 96         1.712                 0.129             0.105
# 97         1.712                 0.129             0.110
# 98         1.712                 0.129             0.084
# 99         1.602                 0.115               NaN
#
#     silhouette_score_stringer
# 0                         NaN
# 1                      -0.118
# 2                      -0.118
# 3                      -0.119
# 4                      -0.120
# ..                        ...
# 95                        NaN
# 96                        NaN
# 97                        NaN
# 98                        NaN
# 99                        NaN
#
# [100 rows x 11 columns]

# %%
# Filter to only rows where n_pcs is 100 - standardise
df_pcs = df[(df["n_pcs"] == 100)]
df_pcs
# Out:
#           model_target mouse_id    layer  n_pcs  test_r2  mean_fev  alpha  \
# 4     vgg19_neural_pc1   m01_d2  conv2_2  100.0    0.407     0.431  1.396
# 9     vgg19_neural_pc1   m01_d2  conv3_4  100.0    0.407     0.430  1.515
# 14    vgg19_neural_pc1   m01_d2  conv4_4  100.0    0.394     0.417  1.616
# 19    vgg19_neural_pc1   m01_d2  conv5_4  100.0    0.279     0.296  1.867
# 24   simclr_neural_pc1   m01_d2       fc  100.0    0.477     0.503  1.702
# 33    vgg19_neural_pc1   m01_d2      fc2  100.0    0.263     0.280  1.583
# 38   simclr_neural_pc1   m01_d2   layer1  100.0    0.425     0.450  3.891
# 47   simclr_neural_pc1   m01_d2   layer2  100.0    0.485     0.513  3.487
# 56   simclr_neural_pc1   m01_d2   layer3  100.0    0.490     0.517  1.911
# 65   simclr_neural_pc1   m01_d2   layer4  100.0    0.470     0.496  1.887
# 74    vgg19_neural_pc1   m02_d3  conv2_2  100.0    0.447     0.488  1.394
# 79    vgg19_neural_pc1   m02_d3  conv3_4  100.0    0.430     0.469  1.524
# 84    vgg19_neural_pc1   m02_d3  conv4_4  100.0    0.391     0.427  1.627
# 89    vgg19_neural_pc1   m02_d3  conv5_4  100.0    0.300     0.328  1.677
# 94   simclr_neural_pc1   m02_d3       fc  100.0    0.483     0.527  1.704
# 103   vgg19_neural_pc1   m02_d3      fc2  100.0    0.303     0.332  1.593
# 108  simclr_neural_pc1   m02_d3   layer1  100.0    0.441     0.481  3.812
# 117  simclr_neural_pc1   m02_d3   layer2  100.0    0.485     0.529  3.438
# 126  simclr_neural_pc1   m02_d3   layer3  100.0    0.555     0.604  1.874
# 135  simclr_neural_pc1   m02_d3   layer4  100.0    0.530     0.577  1.881
# 144   vgg19_neural_pc1   m03_d4  conv2_2  100.0    0.317     0.336  1.397
# 149   vgg19_neural_pc1   m03_d4  conv3_4  100.0    0.298     0.315  1.514
# 154   vgg19_neural_pc1   m03_d4  conv4_4  100.0    0.272     0.289  1.629
# 159   vgg19_neural_pc1   m03_d4  conv5_4  100.0    0.234     0.249  1.830
# 164  simclr_neural_pc1   m03_d4       fc  100.0    0.405     0.428  1.703
# 173   vgg19_neural_pc1   m03_d4      fc2  100.0    0.204     0.218  1.588
# 178  simclr_neural_pc1   m03_d4   layer1  100.0    0.380     0.401  3.757
# 187  simclr_neural_pc1   m03_d4   layer2  100.0    0.443     0.468  3.465
# 196  simclr_neural_pc1   m03_d4   layer3  100.0    0.444     0.469  1.889
# 205  simclr_neural_pc1   m03_d4   layer4  100.0    0.409     0.432  1.879
#
#      alpha_no_pc1  spearman_correlation  silhouette_score  \
# 4           1.423                 0.166            -0.091
# 9           1.462                 0.202            -0.056
# 14          1.645                 0.169             0.000
# 19          1.698                 0.125             0.252
# 24          1.711                 0.188             0.108
# 33          1.589                 0.107             0.447
# 38          4.271                 0.168            -0.114
# 47          3.872                 0.151            -0.080
# 56          1.917                 0.182            -0.005
# 65          1.894                 0.143             0.085
# 74          1.418                 0.128            -0.091
# 79          1.542                 0.167            -0.056
# 84          1.664                 0.135             0.000
# 89          1.709                 0.072             0.252
# 94          1.712                 0.127             0.108
# 103         1.602                 0.071             0.447
# 108         4.127                 0.120            -0.114
# 117         3.883                 0.096            -0.080
# 126         1.878                 0.123            -0.005
# 135         1.888                 0.095             0.085
# 144         1.423                 0.056            -0.091
# 149         1.535                 0.048            -0.056
# 154         1.652                 0.038             0.000
# 159         1.719                 0.041             0.252
# 164         1.714                 0.098             0.108
# 173         1.580                 0.031             0.447
# 178         4.211                 0.099            -0.114
# 187         4.031                 0.120            -0.080
# 196         1.894                 0.118            -0.005
# 205         1.886                 0.082             0.085
#
#      silhouette_score_stringer
# 4                       -0.120
# 9                       -0.136
# 14                      -0.106
# 19                      -0.118
# 24                      -0.065
# 33                      -0.112
# 38                      -0.097
# 47                      -0.076
# 56                      -0.081
# 65                      -0.071
# 74                      -0.135
# 79                      -0.124
# 84                      -0.112
# 89                      -0.110
# 94                         NaN
# 103                     -0.099
# 108                        NaN
# 117                        NaN
# 126                        NaN
# 135                        NaN
# 144                     -0.119
# 149                     -0.130
# 154                     -0.118
# 159                     -0.128
# 164                     -0.048
# 173                     -0.111
# 178                     -0.104
# 187                     -0.086
# 196                     -0.075
# 205                     -0.068

# %%
# Group by layer and compute mean of each metric
avg_metrics = df_pcs.groupby(["model_target", "layer"]).mean(numeric_only=True).reset_index()
avg_metrics
# Out:
#         model_target    layer  n_pcs   test_r2  mean_fev     alpha  \
# 0  simclr_neural_pc1       fc  100.0  0.455000  0.486000  1.703000
# 1  simclr_neural_pc1   layer1  100.0  0.415333  0.444000  3.820000
# 2  simclr_neural_pc1   layer2  100.0  0.471000  0.503333  3.463333
# 3  simclr_neural_pc1   layer3  100.0  0.496333  0.530000  1.891333
# 4  simclr_neural_pc1   layer4  100.0  0.469667  0.501667  1.882333
# 5   vgg19_neural_pc1  conv2_2  100.0  0.390333  0.418333  1.395667
# 6   vgg19_neural_pc1  conv3_4  100.0  0.378333  0.404667  1.517667
# 7   vgg19_neural_pc1  conv4_4  100.0  0.352333  0.377667  1.624000
# 8   vgg19_neural_pc1  conv5_4  100.0  0.271000  0.291000  1.791333
# 9   vgg19_neural_pc1      fc2  100.0  0.256667  0.276667  1.588000
#
#    alpha_no_pc1  spearman_correlation  silhouette_score  \
# 0      1.712333              0.137667             0.108
# 1      4.203000              0.129000            -0.114
# 2      3.928667              0.122333            -0.080
# 3      1.896333              0.141000            -0.005
# 4      1.889333              0.106667             0.085
# 5      1.421333              0.116667            -0.091
# 6      1.513000              0.139000            -0.056
# 7      1.653667              0.114000             0.000
# 8      1.708667              0.079333             0.252
# 9      1.590333              0.069667             0.447
#
#    silhouette_score_stringer
# 0                  -0.056500
# 1                  -0.100500
# 2                  -0.081000
# 3                  -0.078000
# 4                  -0.069500
# 5                  -0.124667
# 6                  -0.130000
# 7                  -0.112000
# 8                  -0.118667
# 9                  -0.107333

# %%
# Get model name
avg_metrics["model"] = avg_metrics["model_target"].str.extract(r"(simclr|vgg19|gabor)")

# RSA: Compute SEM and merge
rsa_sem_df = df_pcs.groupby('layer')['spearman_correlation'].sem().reset_index()
rsa_sem_df.columns = ['layer', 'sem_spearman_correlation']
avg_metrics = avg_metrics.merge(rsa_sem_df, on='layer', how='left')

# FEV: Compute SEM and merge
fev_sem_df = df_pcs.groupby('layer')['mean_fev'].sem().reset_index()
fev_sem_df.columns = ['layer', 'sem_mean_fev']
avg_metrics = avg_metrics.merge(fev_sem_df, on='layer', how='left')

MAX_SEM = 0.005  # or test 0.025, 0.02
# avg_metrics['sem_mean_fev_plot'] = avg_metrics['sem_mean_fev'].clip(upper=MAX_SEM)
# avg_metrics['sem_spearman_correlation_plot'] = avg_metrics['sem_spearman_correlation'].clip(upper=MAX_SEM)
avg_metrics['sem_mean_fev_plot'] = avg_metrics['sem_mean_fev']
avg_metrics['sem_spearman_correlation_plot'] = avg_metrics['sem_spearman_correlation']

avg_metrics
# Out:
#         model_target    layer  n_pcs   test_r2  mean_fev     alpha  \
# 0  simclr_neural_pc1       fc  100.0  0.455000  0.486000  1.703000
# 1  simclr_neural_pc1   layer1  100.0  0.415333  0.444000  3.820000
# 2  simclr_neural_pc1   layer2  100.0  0.471000  0.503333  3.463333
# 3  simclr_neural_pc1   layer3  100.0  0.496333  0.530000  1.891333
# 4  simclr_neural_pc1   layer4  100.0  0.469667  0.501667  1.882333
# 5   vgg19_neural_pc1  conv2_2  100.0  0.390333  0.418333  1.395667
# 6   vgg19_neural_pc1  conv3_4  100.0  0.378333  0.404667  1.517667
# 7   vgg19_neural_pc1  conv4_4  100.0  0.352333  0.377667  1.624000
# 8   vgg19_neural_pc1  conv5_4  100.0  0.271000  0.291000  1.791333
# 9   vgg19_neural_pc1      fc2  100.0  0.256667  0.276667  1.588000
#
#    alpha_no_pc1  spearman_correlation  silhouette_score  \
# 0      1.712333              0.137667             0.108
# 1      4.203000              0.129000            -0.114
# 2      3.928667              0.122333            -0.080
# 3      1.896333              0.141000            -0.005
# 4      1.889333              0.106667             0.085
# 5      1.421333              0.116667            -0.091
# 6      1.513000              0.139000            -0.056
# 7      1.653667              0.114000             0.000
# 8      1.708667              0.079333             0.252
# 9      1.590333              0.069667             0.447
#
#    silhouette_score_stringer   model  sem_spearman_correlation  sem_mean_fev  \
# 0                  -0.056500  simclr                  0.026523      0.029816
# 1                  -0.100500  simclr                  0.020421      0.023288
# 2                  -0.081000  simclr                  0.015920      0.018260
# 3                  -0.078000  simclr                  0.020551      0.039509
# 4                  -0.069500  simclr                  0.018550      0.041954
# 5                  -0.124667   vgg19                  0.032256      0.044333
# 6                  -0.130000   vgg19                  0.046608      0.046225
# 7                  -0.112000   vgg19                  0.039247      0.044427
# 8                  -0.118667   vgg19                  0.024524      0.022942
# 9                  -0.107333   vgg19                  0.021949      0.032951
#
#    sem_mean_fev_plot  sem_spearman_correlation_plot
# 0           0.029816                       0.026523
# 1           0.023288                       0.020421
# 2           0.018260                       0.015920
# 3           0.039509                       0.020551
# 4           0.041954                       0.018550
# 5           0.044333                       0.032256
# 6           0.046225                       0.046608
# 7           0.044427                       0.039247
# 8           0.022942                       0.024524
# 9           0.032951                       0.021949

# %%
for model_name, group in avg_metrics.groupby('model'):
    r, p = spearmanr(group['spearman_correlation'], group['mean_fev'])
    print(f"{model_name}: Spearman r = {r:.3f}, p = {p:.3f}")
# Out:
# simclr: Spearman r = 0.200, p = 0.747
# vgg19: Spearman r = 0.900, p = 0.037

# %%
df_simclr = avg_metrics[avg_metrics["model"] == "simclr"]
plot = plot_fev_vs_metric_scatter(df_simclr, simclr_colours, "spearman_correlation", "Spearman correlation")
plt.savefig("../bar/figures/fev_vs_rsa_simclr_neural_pc1.svg", format='svg', bbox_inches='tight', dpi=300)
plt.show()

# %%
df_vgg19 = avg_metrics[avg_metrics["model"] == "vgg19"]
plot = plot_fev_vs_metric_scatter(df_vgg19, vgg19_colours, "spearman_correlation", "Spearman correlation",)
plt.savefig("../bar/figures/fev_vs_rsa_vgg19_neural_pc1.svg", format='svg', bbox_inches='tight', dpi=300)
plt.show()
