# %%
import json
import pandas as pd
from pathlib import Path

paths = [
    Path("../../analysis/mouse_m01_d2/results/simclr_neural_pc1_m01_d2.json"),
    Path("../../analysis/mouse_m02_d3/results/simclr_neural_pc1_m02_d3.json"),
    Path("../../analysis/mouse_m03_d4/results/simclr_neural_pc1_m03_d4.json")
]

all_data = []
for path in paths:
    with open(path, "r") as f:
        data = json.load(f)
        all_data.extend(data)

df = pd.DataFrame(all_data)
df = df.sort_values(["mouse_id", "layer", "n_pcs"], na_position='first').reset_index(drop=True)

print(f"Loaded {len(df)} rows from {len(paths)} files.")
df.head(100)
# Out:
# Loaded 135 rows from 3 files.
#          model_target mouse_id   layer  n_pcs  test_r2  mean_fev  alpha  \
# 0   simclr_neural_pc1   m01_d2      fc    NaN    0.492     0.520  1.702
# 1   simclr_neural_pc1   m01_d2      fc   10.0    0.367     0.389  1.702
# 2   simclr_neural_pc1   m01_d2      fc   20.0    0.391     0.414  1.702
# 3   simclr_neural_pc1   m01_d2      fc   50.0    0.470     0.497  1.702
# 4   simclr_neural_pc1   m01_d2      fc  100.0    0.477     0.503  1.702
# ..                ...      ...     ...    ...      ...       ...    ...
# 95  simclr_neural_pc1   m03_d4      fc  200.0    0.407     0.430  1.703
# 96  simclr_neural_pc1   m03_d4      fc  300.0    0.409     0.432  1.703
# 97  simclr_neural_pc1   m03_d4      fc  400.0    0.409     0.432  1.703
# 98  simclr_neural_pc1   m03_d4      fc  500.0    0.409     0.433  1.703
# 99  simclr_neural_pc1   m03_d4  layer1    NaN    0.365     0.386  3.757
#
#     alpha_no_pc1  spearman_correlation  silhouette_score
# 0          1.711                 0.188               NaN
# 1          1.711                 0.179             0.092
# 2          1.711                 0.184             0.092
# 3          1.711                 0.187             0.102
# 4          1.711                 0.188             0.108
# ..           ...                   ...               ...
# 95         1.714                 0.098             0.107
# 96         1.714                 0.098             0.105
# 97         1.714                 0.098             0.110
# 98         1.714                 0.098             0.084
# 99         4.211                 0.164               NaN
#
# [100 rows x 10 columns]

# %%
# Filter to only rows where n_pcs == 100
df_100pcs = df[df["n_pcs"] == 100]
df_100pcs
# Out:
#           model_target mouse_id   layer  n_pcs  test_r2  mean_fev  alpha  \
# 4    simclr_neural_pc1   m01_d2      fc  100.0    0.477     0.503  1.702
# 13   simclr_neural_pc1   m01_d2  layer1  100.0    0.425     0.450  3.891
# 22   simclr_neural_pc1   m01_d2  layer2  100.0    0.485     0.513  3.487
# 31   simclr_neural_pc1   m01_d2  layer3  100.0    0.490     0.517  1.911
# 40   simclr_neural_pc1   m01_d2  layer4  100.0    0.470     0.496  1.887
# 49   simclr_neural_pc1   m02_d3      fc  100.0    0.483     0.527  1.704
# 58   simclr_neural_pc1   m02_d3  layer1  100.0    0.441     0.481  3.812
# 67   simclr_neural_pc1   m02_d3  layer2  100.0    0.485     0.529  3.438
# 76   simclr_neural_pc1   m02_d3  layer3  100.0    0.555     0.604  1.874
# 85   simclr_neural_pc1   m02_d3  layer4  100.0    0.530     0.577  1.881
# 94   simclr_neural_pc1   m03_d4      fc  100.0    0.405     0.428  1.703
# 103  simclr_neural_pc1   m03_d4  layer1  100.0    0.380     0.401  3.757
# 112  simclr_neural_pc1   m03_d4  layer2  100.0    0.443     0.468  3.465
# 121  simclr_neural_pc1   m03_d4  layer3  100.0    0.444     0.469  1.889
# 130  simclr_neural_pc1   m03_d4  layer4  100.0    0.409     0.432  1.879
#
#      alpha_no_pc1  spearman_correlation  silhouette_score
# 4           1.711                 0.188             0.108
# 13          4.271                 0.168            -0.114
# 22          3.872                 0.151            -0.080
# 31          1.917                 0.182            -0.005
# 40          1.894                 0.143             0.085
# 49          1.712                 0.127             0.108
# 58          4.127                 0.120            -0.114
# 67          3.883                 0.096            -0.080
# 76          1.878                 0.123            -0.005
# 85          1.888                 0.095             0.085
# 94          1.714                 0.098             0.108
# 103         4.211                 0.099            -0.114
# 112         4.031                 0.120            -0.080
# 121         1.894                 0.118            -0.005
# 130         1.886                 0.082             0.085

# %%
# Group by layer and compute mean of each metric
avg_metrics = df_100pcs.groupby("layer").mean(numeric_only=True).reset_index()
avg_metrics
# Out:
#     layer  n_pcs   test_r2  mean_fev     alpha  alpha_no_pc1  \
# 0      fc  100.0  0.455000  0.486000  1.703000      1.712333
# 1  layer1  100.0  0.415333  0.444000  3.820000      4.203000
# 2  layer2  100.0  0.471000  0.503333  3.463333      3.928667
# 3  layer3  100.0  0.496333  0.530000  1.891333      1.896333
# 4  layer4  100.0  0.469667  0.501667  1.882333      1.889333
#
#    spearman_correlation  silhouette_score
# 0              0.137667             0.108
# 1              0.129000            -0.114
# 2              0.122333            -0.080
# 3              0.141000            -0.005
# 4              0.106667             0.085

# %%
from sklearn.preprocessing import MinMaxScaler
import numpy as np
import matplotlib.pyplot as plt

# Normalise each metric to [0, 1]
metrics = ['mean_fev', 'alpha', 'silhouette_score', 'spearman_correlation']
scaler = MinMaxScaler()
avg_metrics_scaled = avg_metrics.copy()
avg_metrics_scaled[metrics] = scaler.fit_transform(avg_metrics[metrics])

labels = metrics
num_vars = len(labels)

angles = np.linspace(0, 2 * np.pi, num_vars, endpoint=False).tolist()
angles += angles[:1]  # close the loop

fig, ax = plt.subplots(figsize=(6, 6), subplot_kw=dict(polar=True))

for i, row in avg_metrics_scaled.iterrows():
    values = row[metrics].tolist()
    values += values[:1]  # close the loop
    ax.plot(angles, values, label=row['layer'])
    ax.fill(angles, values, alpha=0.1)

ax.set_xticks(angles[:-1])
ax.set_xticklabels(labels)
ax.set_yticks([0.2, 0.5, 0.8])
ax.set_yticklabels(['0.2', '0.5', '0.8'])
ax.set_ylim(0, 1)
ax.legend(loc='upper right', bbox_to_anchor=(1.2, 1.1))
plt.title("PC1 Neural Data: Metrics Across SimCLR Layers")
plt.show()
